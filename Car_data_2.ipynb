# %%
import pandas as pd

# %%
cars_2_data=pd.read_csv('Cars_2_data.csv')
cars_2_data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
cars_2_data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
cars_2_data.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200   sedan        rwd          front      109.1  ...         141        mpfi
# 201   sedan        rwd          front      109.1  ...         141        mpfi
# 202   sedan        rwd          front      109.1  ...         173        mpfi
# 203   sedan        rwd          front      109.1  ...         145         idi
# 204   sedan        rwd          front      109.1  ...         141        mpfi
#
# ...

# %%
cars_2_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
cars_2_data.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
cars_2_data.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
cars_data['car_ID'].mean()
# Out:
# 103.0

# %%
cars_data['car_ID'].fillna(cars_data['car_ID'].mean(),inplace=True)

# %%
cars_data['symboling'].fillna(cars_data['symboling'].mean(),inplace=True)

# %%
cars_data['curbweight'].fillna(cars_data['curbweight'].mean(),inplace=True)

# %%
cars_data['horsepower'].fillna(cars_data['horsepower'].mean(),inplace=True)

# %%
cars_data['peakrpm'].fillna(cars_data['horsepower'].mean(),inplace=True)

# %%
cars_data['citympg'].fillna(cars_data['horsepower'].mean(),inplace=True)

# %%
cars_data['highwaympg'].fillna(cars_data['symboling'].mean(),inplace=True)

# %%
cars_data.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
cars_data['wheelbase'].fillna(cars_data['wheelbase'].mean(),inplace=True)

# %%
cars_data['carlength'].fillna(cars_data['carlength'].mean(),inplace=True)

# %%
cars_data['carwidth'].fillna(cars_data['carwidth'].mean(),inplace=True)

# %%
cars_data['carheight'].fillna(cars_data['carheight'].mean(),inplace=True)

# %%
cars_data['boreratio'].fillna(cars_data['boreratio'].mean(),inplace=True)

# %%
cars_data['stroke'].fillna(cars_data['stroke'].mean(),inplace=True)

# %%
cars_data['compressionratio'].fillna(cars_data['compressionratio'].mean(),inplace=True)

# %%
cars_data['price'].fillna(cars_data['price'].mean(),inplace=True)

# %%
cars_data.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
import numpy as np

# %%
Car_Name=cars_data['CarName'].mode()
Car_Name
# Out:
# 0       peugeot 504
# 1    toyota corolla
# 2     toyota corona
# Name: CarName, dtype: object

# %%
fuel_type=cars_data['fueltype'].mode()
fuel_type
# Out:
# 0    gas
# Name: fueltype, dtype: object

# %%
aspiration=cars_data['aspiration'].mode()
aspiration
# Out:
# 0    std
# Name: aspiration, dtype: object

# %%
door_number=cars_data['doornumber'].mode()
door_number
# Out:
# 0    four
# Name: doornumber, dtype: object

# %%
car_body =cars_data['carbody'].mode()
car_body
# Out:
# 0    sedan
# Name: carbody, dtype: object

# %%
drive_wheel =cars_data['drivewheel'].mode()
drive_wheel
# Out:
# 0    fwd
# Name: drivewheel, dtype: object

# %%
engine_type =cars_data['enginetype'].mode()
engine_type
# Out:
# 0    ohc
# Name: enginetype, dtype: object

# %%
cylinder_number =cars_data['cylindernumber'].mode()
cylinder_number
# Out:
# 0    four
# Name: cylindernumber, dtype: object

# %%
fuel_system =cars_data['fuelsystem'].mode()
fuel_system
# Out:
# 0    mpfi
# Name: fuelsystem, dtype: object

# %%
cars_data['CarName'].replace(np.nan,'peugeot 504',inplace=True)

# %%
cars_data['fueltype'].replace(np.nan,' gas',inplace=True)

# %%
cars_data['aspiration'].replace(np.nan,'std',inplace=True)

# %%
cars_data['doornumber'].replace(np.nan,'four',inplace=True)

# %%
cars_data['carbody'].replace(np.nan,'sedan',inplace=True)

# %%
cars_data['drivewheel'].replace(np.nan,'fwd',inplace=True)

# %%
cars_data['enginetype'].replace(np.nan,'ohc',inplace=True)

# %%
cars_data['cylindernumber'].replace(np.nan,' four',inplace=True)

# %%
cars_data['fuelsystem'].replace(np.nan,'mpfi',inplace=True)

# %%
cars_data.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
cars_data.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
cars_data['CarName'].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
# ...

# %%
cars_data['fueltype'].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
cars_data['aspiration'].unique()
# Out:
# array(['std', 'turbo'], dtype=object)

# %%
cars_data['doornumber'].unique()
# Out:
# array(['two', 'four'], dtype=object)

# %%
cars_data['drivewheel'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
cars_data['enginetype'].unique()
# Out:
# array(['dohc', 'ohcv', 'ohc', 'l', 'rotor', 'ohcf', 'dohcv'], dtype=object)

# %%
cars_data['cylindernumber'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
cars_data['fuelsystem'].unique()
# Out:
# array(['mpfi', '2bbl', 'mfi', '1bbl', 'spfi', '4bbl', 'idi', 'spdi'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
cars_data['labeled_carname']=encoder.fit_transform(cars_data['CarName'])

# %%
cars_data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  fuelsystem  \
# 0  convertible        rwd          front       88.6  ...        mpfi
# 1  convertible        rwd          front       88.6  ...        mpfi
# 2    hatchback        rwd          front       94.5  ...        mpfi
# 3        sedan        fwd          front       99.8  ...        mpfi
# 4        sedan        4wd          front       99.4  ...        mpfi
#
#    boreratio  stroke  compressionratio horsepower peakrpm  citympg highwaympg  \
# ...

# %%
cars_data.drop_duplicates('CarName')
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 196     197         -2               volvo 244dl      gas        std
# 197     198         -1                 volvo 245      gas        std
# 198     199         -2               volvo 264gl      gas      turbo
# 199     200         -1              volvo diesel      gas      turbo
# 203     204         -1                 volvo 246   diesel      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
cars_data['labelled_fuel_type']=encoder.fit_transform(cars_data['fueltype'])

# %%
cars_data.drop_duplicates('fueltype')
# Out:
#     car_ID  symboling             CarName fueltype aspiration doornumber  \
# 0        1          3  alfa-romero giulia      gas        std        two
# 63      64          0    mazda glc deluxe   diesel        std       four
#
#         carbody drivewheel enginelocation  wheelbase  ...  boreratio  stroke  \
# 0   convertible        rwd          front       88.6  ...       3.47    2.68
# 63        sedan        fwd          front       98.8  ...       3.39    3.39
#
#     compressionratio  horsepower peakrpm citympg  highwaympg    price  \
# 0                9.0         111    5000      21          27  13495.0
# 63              22.7          64    4650      36          42  10795.0
#
#     labeled_carname  labelled_fuel_type
# 0                 2                   1
# 63               58                   0
#
# [2 rows x 28 columns]

# %%
cars_data['labelled_aspiration']=encoder.fit_transform(cars_data['aspiration'])

# %%
cars_data.drop_duplicates('aspiration')
# Out:
#    car_ID  symboling             CarName fueltype aspiration doornumber  \
# 0       1          3  alfa-romero giulia      gas        std        two
# 8       9          1           audi 4000      gas      turbo       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  stroke  \
# 0  convertible        rwd          front       88.6  ...    2.68
# 8        sedan        fwd          front      105.8  ...    3.40
#
#    compressionratio  horsepower  peakrpm citympg highwaympg    price  \
# 0               9.0         111     5000      21         27  13495.0
# 8               8.3         140     5500      17         20  23875.0
#
#   labeled_carname  labelled_fuel_type  labelled_aspiration
# 0               2                   1                    0
# 8               6                   1                    1
#
# [2 rows x 29 columns]

# %%
cars_data['labelled_door_number']=encoder.fit_transform(cars_data['doornumber'])

# %%
cars_data.drop_duplicates('doornumber')
# Out:
#    car_ID  symboling             CarName fueltype aspiration doornumber  \
# 0       1          3  alfa-romero giulia      gas        std        two
# 3       4          2         audi 100 ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  compressionratio  \
# 0  convertible        rwd          front       88.6  ...               9.0
# 3        sedan        fwd          front       99.8  ...              10.0
#
#    horsepower  peakrpm  citympg highwaympg    price  labeled_carname  \
# 0         111     5000       21         27  13495.0                2
# 3         102     5500       24         30  13950.0                4
#
#   labelled_fuel_type  labelled_aspiration  labelled_door_number
# 0                  1                    0                     1
# 3                  1                    0                     0
#
# [2 rows x 30 columns]

# %%
cars_data['labelled_car_body']=encoder.fit_transform(cars_data['carbody'])

# %%
cars_data.drop_duplicates('carbody')
# Out:
#     car_ID  symboling                   CarName fueltype aspiration  \
# 0        1          3        alfa-romero giulia      gas        std
# 2        3          1  alfa-romero Quadrifoglio      gas        std
# 3        4          2               audi 100 ls      gas        std
# 7        8          1                 audi 5000      gas        std
# 69      70          0             buick century   diesel      turbo
#
#    doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# 0         two  convertible        rwd          front       88.6  ...
# 2         two    hatchback        rwd          front       94.5  ...
# 3        four        sedan        fwd          front       99.8  ...
# 7        four        wagon        fwd          front      105.8  ...
# 69        two      hardtop        rwd          front      106.7  ...
#
#     horsepower  peakrpm  citympg  highwaympg    price labeled_carname  \
# ...

# %%
cars_data['labelled_drive_wheel']=encoder.fit_transform(cars_data['drivewheel'])

# %%
cars_data.drop_duplicates('drivewheel')
# Out:
#    car_ID  symboling             CarName fueltype aspiration doornumber  \
# 0       1          3  alfa-romero giulia      gas        std        two
# 3       4          2         audi 100 ls      gas        std       four
# 4       5          2          audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  peakrpm  citympg  \
# 0  convertible        rwd          front       88.6  ...     5000       21
# 3        sedan        fwd          front       99.8  ...     5500       24
# 4        sedan        4wd          front       99.4  ...     5500       18
#
#    highwaympg    price labeled_carname labelled_fuel_type  \
# 0          27  13495.0               2                  1
# 3          30  13950.0               4                  1
# 4          22  17450.0               5                  1
#
#    labelled_aspiration labelled_door_number  labelled_car_body  \
# 0                    0                    1                  0
# ...

# %%
cars_data['labelled_engine_location']=encoder.fit_transform(cars_data['enginelocation'])

# %%
cars_data.drop_duplicates('enginelocation')
# Out:
#      car_ID  symboling             CarName fueltype aspiration doornumber  \
# 0         1          3  alfa-romero giulia      gas        std        two
# 126     127          3   porcshce panamera      gas        std        two
#
#          carbody drivewheel enginelocation  wheelbase  ...  citympg  \
# 0    convertible        rwd          front       88.6  ...       21
# 126      hardtop        rwd           rear       89.5  ...       17
#
#      highwaympg    price  labeled_carname labelled_fuel_type  \
# 0            27  13495.0                2                  1
# 126          25  32528.0               95                  1
#
#     labelled_aspiration  labelled_door_number labelled_car_body  \
# 0                     0                     1                 0
# 126                   0                     1                 1
#
#      labelled_drive_wheel  labelled_engine_location
# 0                       2                         0
# ...

# %%
cars_data['labelled_engine_type']=encoder.fit_transform(cars_data['enginetype'])

# %%
cars_data.drop_duplicates('enginetype')
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 18       19          2          chevrolet impala      gas        std
# 55       56          3                 mazda 626      gas        std
# 126     127          3         porcshce panamera      gas        std
# 129     130          1           porsche cayenne      gas        std
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# 0          two  convertible        rwd          front       88.6  ...
# 2          two    hatchback        rwd          front       94.5  ...
# 3         four        sedan        fwd          front       99.8  ...
# 18         two    hatchback        fwd          front       88.4  ...
# ...

# %%
cars_data['labelled_cylinder_number']=encoder.fit_transform(cars_data['cylindernumber'])

# %%
cars_data.drop_duplicates('cylindernumber')
# Out:
#     car_ID  symboling                   CarName fueltype aspiration  \
# 0        1          3        alfa-romero giulia      gas        std
# 2        3          1  alfa-romero Quadrifoglio      gas        std
# 4        5          2                audi 100ls      gas        std
# 18      19          2          chevrolet impala      gas        std
# 49      50          0                 jaguar xk      gas        std
# 55      56          3                 mazda 626      gas        std
# 71      72         -1   buick opel isuzu deluxe      gas        std
#
#    doornumber      carbody drivewheel enginelocation  wheelbase  ...    price  \
# 0         two  convertible        rwd          front       88.6  ...  13495.0
# 2         two    hatchback        rwd          front       94.5  ...  16500.0
# 4        four        sedan        4wd          front       99.4  ...  17450.0
# 18        two    hatchback        fwd          front       88.4  ...   5151.0
# ...

# %%
cars_data['labelled_fuel_system']=encoder.fit_transform(cars_data['fuelsystem'])

# %%
cars_data.drop_duplicates('fuelsystem')
# Out:
#     car_ID  symboling                    CarName fueltype aspiration  \
# 0        1          3         alfa-romero giulia      gas        std
# 18      19          2           chevrolet impala      gas        std
# 29      30          3  dodge coronet custom (sw)      gas      turbo
# 30      31          2                honda civic      gas        std
# 46      47          2               isuzu D-Max       gas        std
# 55      56          3                  mazda 626      gas        std
# 63      64          0           mazda glc deluxe   diesel        std
# 79      80          1              mitsubishi g4      gas      turbo
#
#    doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# 0         two  convertible        rwd          front       88.6  ...
# 18        two    hatchback        fwd          front       88.4  ...
# 29        two    hatchback        fwd          front       95.9  ...
# ...

# %%
x=cars_data.drop(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
       'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
       'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
       'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
       'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
       'price'], axis=1)
y=cars_data['price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train.shape,x_test.shape,x.shape
# Out:
# ((164, 10), (41, 10), (205, 10))

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred=model.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,pred)*100
# Out:
# 63.10532287613392

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mean_absolute_error(y_test,pred)
# Out:
# 3446.404438972605

# %%
mean_squared_error(y_test,pred)
# Out:
# 17886893.07165973

# %%
x.columns
# Out:
# Index(['labeled_carname', 'labelled_fuel_type', 'labelled_aspiration',
#        'labelled_door_number', 'labelled_car_body', 'labelled_drive_wheel',
#        'labelled_engine_location', 'labelled_engine_type',
#        'labelled_cylinder_number', 'labelled_fuel_system'],
#       dtype='object')
